# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv('C://Users//Ирина//Downloads//habr_data (2).csv')

# %%
df
# Out:
#                                          Unnamed: 0  \
# 0                              /ru/articles/734892/
# 1                              /ru/articles/734890/
# 2                              /ru/articles/734888/
# 3                              /ru/articles/734830/
# 4           /ru/companies/selectel/articles/734860/
# ..                                              ...
# 995                            /ru/articles/728896/
# 996  /ru/companies/sportmaster_lab/articles/728880/
# 997                            /ru/articles/723668/
# 998                            /ru/articles/728870/
# 999                            /ru/articles/728868/
#
#                                              item name Время чтения Сложность  \
# 0    Мультяшная графика продаётся лучше реалистично...        8 мин   Средний
# 1    Picture in Picture Mode в android. Показываем ...        5 мин   Простой
# 2                 Много нас, а GPU один. Как делиться?        6 мин   Простой
# ...

# %%
df.pop('Unnamed: 0')
# Out:
# 0                                /ru/articles/734892/
# 1                                /ru/articles/734890/
# 2                                /ru/articles/734888/
# 3                                /ru/articles/734830/
# 4             /ru/companies/selectel/articles/734860/
#                             ...
# 995                              /ru/articles/728896/
# 996    /ru/companies/sportmaster_lab/articles/728880/
# 997                              /ru/articles/723668/
# 998                              /ru/articles/728870/
# 999                              /ru/articles/728868/
# Name: Unnamed: 0, Length: 1000, dtype: object

# %%
df
# Out:
#                                              item name Время чтения Сложность  \
# 0    Мультяшная графика продаётся лучше реалистично...        8 мин   Средний
# 1    Picture in Picture Mode в android. Показываем ...        5 мин   Простой
# 2                 Много нас, а GPU один. Как делиться?        6 мин   Простой
# 3    Ближайшие бесплатные мероприятия по разработке...        2 мин   Простой
# 4    Одноплатник Orange Pi 5 Plus: характеристики и...        4 мин       NaN
# ..                                                 ...          ...       ...
# 995          Java на стероидах, или опыт работы с Jmix        7 мин   Средний
# 996           «Чистый» код, ужасная производительность       16 мин       NaN
# 997  PostgreSQL под капотом. Часть 5. Простой SELEC...       42 мин       NaN
# 998                            Чат в терминале на Rust       36 мин   Простой
# 999           ChatGPT на Java пишет renamer для файлов        4 мин   Простой
#
# ...

# %%
df['Сложность'] = df['Сложность'].fillna(0)

# %%
df['Сложность'] = df['Сложность'].replace(['Простой', 'Средний', 'Сложный'],[1, 2, 3])

# %%
df
# Out:
#                                              item name Время чтения  \
# 0    Мультяшная графика продаётся лучше реалистично...        8 мин
# 1    Picture in Picture Mode в android. Показываем ...        5 мин
# 2                 Много нас, а GPU один. Как делиться?        6 мин
# 3    Ближайшие бесплатные мероприятия по разработке...        2 мин
# 4    Одноплатник Orange Pi 5 Plus: характеристики и...        4 мин
# ..                                                 ...          ...
# 995          Java на стероидах, или опыт работы с Jmix        7 мин
# 996           «Чистый» код, ужасная производительность       16 мин
# 997  PostgreSQL под капотом. Часть 5. Простой SELEC...       42 мин
# 998                            Чат в терминале на Rust       36 мин
# 999           ChatGPT на Java пишет renamer для файлов        4 мин
#
#      Сложность Количество просмотров  В закладках  Комментарии         Автор  \
# ...

# %%
df['Сложность'] = df['Сложность'].replace([0],[','])

# %%
df
# Out:
#                                              item name Время чтения Сложность  \
# 0    Мультяшная графика продаётся лучше реалистично...        8 мин         2
# 1    Picture in Picture Mode в android. Показываем ...        5 мин         1
# 2                 Много нас, а GPU один. Как делиться?        6 мин         1
# 3    Ближайшие бесплатные мероприятия по разработке...        2 мин         1
# 4    Одноплатник Orange Pi 5 Plus: характеристики и...        4 мин         ,
# ..                                                 ...          ...       ...
# 995          Java на стероидах, или опыт работы с Jmix        7 мин         2
# 996           «Чистый» код, ужасная производительность       16 мин         ,
# 997  PostgreSQL под капотом. Часть 5. Простой SELEC...       42 мин         ,
# 998                            Чат в терминале на Rust       36 мин         1
# 999           ChatGPT на Java пишет renamer для файлов        4 мин         1
#
# ...

# %%
df[['Время чтения', 'мин']] = df['Время чтения']. str.split(' ', 1 , expand= True )

# %%
df
# Out:
#                                              item name Время чтения Сложность  \
# 0    Мультяшная графика продаётся лучше реалистично...            8         2
# 1    Picture in Picture Mode в android. Показываем ...            5         1
# 2                 Много нас, а GPU один. Как делиться?            6         1
# 3    Ближайшие бесплатные мероприятия по разработке...            2         1
# 4    Одноплатник Orange Pi 5 Plus: характеристики и...            4         ,
# ..                                                 ...          ...       ...
# 995          Java на стероидах, или опыт работы с Jmix            7         2
# 996           «Чистый» код, ужасная производительность           16         ,
# 997  PostgreSQL под капотом. Часть 5. Простой SELEC...           42         ,
# 998                            Чат в терминале на Rust           36         1
# 999           ChatGPT на Java пишет renamer для файлов            4         1
#
# ...

# %%
df.pop('мин')
# Out:
# 0      мин
# 1      мин
# 2      мин
# 3      мин
# 4      мин
#       ...
# 995    мин
# 996    мин
# 997    мин
# 998    мин
# 999    мин
# Name: мин, Length: 1000, dtype: object

# %%
df
# Out:
#                                              item name Время чтения Сложность  \
# 0    Мультяшная графика продаётся лучше реалистично...            8         2
# 1    Picture in Picture Mode в android. Показываем ...            5         1
# 2                 Много нас, а GPU один. Как делиться?            6         1
# 3    Ближайшие бесплатные мероприятия по разработке...            2         1
# 4    Одноплатник Orange Pi 5 Plus: характеристики и...            4         ,
# ..                                                 ...          ...       ...
# 995          Java на стероидах, или опыт работы с Jmix            7         2
# 996           «Чистый» код, ужасная производительность           16         ,
# 997  PostgreSQL под капотом. Часть 5. Простой SELEC...           42         ,
# 998                            Чат в терминале на Rust           36         1
# 999           ChatGPT на Java пишет renamer для файлов            4         1
#
# ...

# %%
df = df.astype({'Время чтения': np.int64})

# %%
df
# Out:
#                                              item name  Время чтения  \
# 0    Мультяшная графика продаётся лучше реалистично...             8
# 1    Picture in Picture Mode в android. Показываем ...             5
# 2                 Много нас, а GPU один. Как делиться?             6
# 3    Ближайшие бесплатные мероприятия по разработке...             2
# 4    Одноплатник Orange Pi 5 Plus: характеристики и...             4
# ..                                                 ...           ...
# 995          Java на стероидах, или опыт работы с Jmix             7
# 996           «Чистый» код, ужасная производительность            16
# 997  PostgreSQL под капотом. Часть 5. Простой SELEC...            42
# 998                            Чат в терминале на Rust            36
# 999           ChatGPT на Java пишет renamer для файлов             4
#
#     Сложность Количество просмотров  В закладках  Комментарии         Автор  \
# ...

# %%
df = df.astype({'Количество просмотров': np.int64})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [20], in <cell line: 1>()
# ----> 1 df = df.astype({'Количество просмотров': np.int64})
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:5898, in NDFrame.astype(self, dtype, copy, errors)
#    5896             res_col = col.copy() if copy else col
#    5897         else:
# -> 5898             res_col = col.astype(dtype=cdt, copy=copy, errors=errors)
#    5899         results.append(res_col)
#    5901 elif is_extension_array_dtype(dtype) and self.ndim > 1:
#    5902     # GH 18099/22869: columnwise conversion to extension dtype
#    5903     # GH 24704: use iloc to handle duplicate column names
#    5904     # TODO(EA2D): special case not needed with 2D EAs
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:5912, in NDFrame.astype(self, dtype, copy, errors)
# ...
