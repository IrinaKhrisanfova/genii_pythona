# %%
import pandas as pd

# %%
df = pd.read_csv('C://Users//Ирина//Downloads//habr_data (2).csv')

# %%
df.pop('Автор')
# Out:
# 0          @Kallist
# 1       @cookie2727
# 2            @Antra
# 3        @ITMeeting
# 4        @Seleditor
#            ...
# 995      @redcollar
# 996     @JustJeremy
# 997       @AshBlade
# 998     @Davydoff33
# 999    @thetka4enko
# Name: Автор, Length: 1000, dtype: object

# %%
df
# Out:
#                                          Unnamed: 0  \
# 0                              /ru/articles/734892/
# 1                              /ru/articles/734890/
# 2                              /ru/articles/734888/
# 3                              /ru/articles/734830/
# 4           /ru/companies/selectel/articles/734860/
# ..                                              ...
# 995                            /ru/articles/728896/
# 996  /ru/companies/sportmaster_lab/articles/728880/
# 997                            /ru/articles/723668/
# 998                            /ru/articles/728870/
# 999                            /ru/articles/728868/
#
#                                              item name Время чтения Сложность  \
# 0    Мультяшная графика продаётся лучше реалистично...        8 мин   Средний
# 1    Picture in Picture Mode в android. Показываем ...        5 мин   Простой
# 2                 Много нас, а GPU один. Как делиться?        6 мин   Простой
# 3    Ближайшие бесплатные мероприятия по разработке...        2 мин   Простой
# 4    Одноплатник Orange Pi 5 Plus: характеристики и...        4 мин       NaN
# ..                                                 ...          ...       ...
# 995          Java на стероидах, или опыт работы с Jmix        7 мин   Средний
# 996           «Чистый» код, ужасная производительность       16 мин       NaN
# 997  PostgreSQL под капотом. Часть 5. Простой SELEC...       42 мин       NaN
# 998                            Чат в терминале на Rust       36 мин   Простой
# 999           ChatGPT на Java пишет renamer для файлов        4 мин   Простой
#
#     Количество просмотров  В закладках  Комментарии  Рейтинг автора  \
# 0                     324            1            1             0.0
# 1                     122            3            0             0.0
# 2                    1.6K            5            6             6.1
# 3                     376            1            0            -0.8
# 4                    3.5K            6           13            49.0
# ..                    ...          ...          ...             ...
# 995                  3.3K           20            2             0.0
# 996                   54K          235          365            49.2
# 997                  3.2K           68            4             6.5
# 998                  3.4K           31            4             5.0
# 999                  2.4K           12            7             4.0
#
#       Время публикации
# 0    2023-05-13, 19:20
# 1    2023-05-13, 18:55
# 2    2023-05-13, 17:57
# 3    2023-05-13, 16:27
# 4    2023-05-13, 12:55
# ..                 ...
# 995  2023-04-13, 14:43
# 996  2023-04-13, 14:23
# 997  2023-04-13, 14:00
# 998  2023-04-13, 13:41
# 999  2023-04-13, 13:41
#
# [1000 rows x 9 columns]

# %%
df['Сложность'] = df['Сложность'].fillna(0)

# %%
df['Сложность'] = df['Сложность'].replace(['Простой', 'Средний', 'Сложный'],[1, 2, 3])

# %%
df
# Out:
#                                          Unnamed: 0  \
# 0                              /ru/articles/734892/
# 1                              /ru/articles/734890/
# 2                              /ru/articles/734888/
# 3                              /ru/articles/734830/
# 4           /ru/companies/selectel/articles/734860/
# ..                                              ...
# 995                            /ru/articles/728896/
# 996  /ru/companies/sportmaster_lab/articles/728880/
# 997                            /ru/articles/723668/
# 998                            /ru/articles/728870/
# 999                            /ru/articles/728868/
#
#                                              item name Время чтения  \
# 0    Мультяшная графика продаётся лучше реалистично...        8 мин
# 1    Picture in Picture Mode в android. Показываем ...        5 мин
# 2                 Много нас, а GPU один. Как делиться?        6 мин
# 3    Ближайшие бесплатные мероприятия по разработке...        2 мин
# 4    Одноплатник Orange Pi 5 Plus: характеристики и...        4 мин
# ..                                                 ...          ...
# 995          Java на стероидах, или опыт работы с Jmix        7 мин
# 996           «Чистый» код, ужасная производительность       16 мин
# 997  PostgreSQL под капотом. Часть 5. Простой SELEC...       42 мин
# 998                            Чат в терминале на Rust       36 мин
# 999           ChatGPT на Java пишет renamer для файлов        4 мин
#
#      Сложность Количество просмотров  В закладках  Комментарии  \
# 0            2                   324            1            1
# 1            1                   122            3            0
# 2            1                  1.6K            5            6
# 3            1                   376            1            0
# 4            0                  3.5K            6           13
# ..         ...                   ...          ...          ...
# 995          2                  3.3K           20            2
# 996          0                   54K          235          365
# 997          0                  3.2K           68            4
# 998          1                  3.4K           31            4
# 999          1                  2.4K           12            7
#
#      Рейтинг автора   Время публикации
# 0               0.0  2023-05-13, 19:20
# 1               0.0  2023-05-13, 18:55
# 2               6.1  2023-05-13, 17:57
# 3              -0.8  2023-05-13, 16:27
# 4              49.0  2023-05-13, 12:55
# ..              ...                ...
# 995             0.0  2023-04-13, 14:43
# 996            49.2  2023-04-13, 14:23
# 997             6.5  2023-04-13, 14:00
# 998             5.0  2023-04-13, 13:41
# 999             4.0  2023-04-13, 13:41
#
# [1000 rows x 9 columns]

# %%
av_column = df['Сложность']. mean (axis= 0 )

# %%
print(av_column)
# Out:
# 1.038

# %%
df['Сложность'] = df['Сложность'].replace([0],[av_column])

# %%
df.pop('Время чтения')
# Out:
# 0
# 1
# 2
# 3
# 4
#       ..
# 995
# 996
# 997
# 998
# 999
# Name: Время чтения, Length: 1000, dtype: object

# %%
df
# Out:
#                                          Unnamed: 0  \
# 0                              /ru/articles/734892/
# 1                              /ru/articles/734890/
# 2                              /ru/articles/734888/
# 3                              /ru/articles/734830/
# 4           /ru/companies/selectel/articles/734860/
# ..                                              ...
# 995                            /ru/articles/728896/
# 996  /ru/companies/sportmaster_lab/articles/728880/
# 997                            /ru/articles/723668/
# 998                            /ru/articles/728870/
# 999                            /ru/articles/728868/
#
#                                              item name Время чтения  \
# 0    Мультяшная графика продаётся лучше реалистично...
# 1    Picture in Picture Mode в android. Показываем ...
# 2                 Много нас, а GPU один. Как делиться?
# 3    Ближайшие бесплатные мероприятия по разработке...
# 4    Одноплатник Orange Pi 5 Plus: характеристики и...
# ..                                                 ...          ...
# 995          Java на стероидах, или опыт работы с Jmix
# 996           «Чистый» код, ужасная производительность
# 997  PostgreSQL под капотом. Часть 5. Простой SELEC...
# 998                            Чат в терминале на Rust
# 999           ChatGPT на Java пишет renamer для файлов
#
#      Сложность Количество просмотров  В закладках  Комментарии  \
# 0        2.000                   324            1            1
# 1        1.000                   122            3            0
# 2        1.000                  1.6K            5            6
# 3        1.000                   376            1            0
# 4        1.038                  3.5K            6           13
# ..         ...                   ...          ...          ...
# 995      2.000                  3.3K           20            2
# 996      1.038                   54K          235          365
# 997      1.038                  3.2K           68            4
# 998      1.000                  3.4K           31            4
# 999      1.000                  2.4K           12            7
#
#      Рейтинг автора   Время публикации     мин
# 0               0.0  2023-05-13, 19:20   8 мин
# 1               0.0  2023-05-13, 18:55   5 мин
# 2               6.1  2023-05-13, 17:57   6 мин
# 3              -0.8  2023-05-13, 16:27   2 мин
# 4              49.0  2023-05-13, 12:55   4 мин
# ..              ...                ...     ...
# 995             0.0  2023-04-13, 14:43   7 мин
# 996            49.2  2023-04-13, 14:23  16 мин
# 997             6.5  2023-04-13, 14:00  42 мин
# 998             5.0  2023-04-13, 13:41  36 мин
# 999             4.0  2023-04-13, 13:41   4 мин
#
# [1000 rows x 10 columns]

# %%
# Out:
#                                          Unnamed: 0  \
# 0                              /ru/articles/734892/
# 1                              /ru/articles/734890/
# 2                              /ru/articles/734888/
# 3                              /ru/articles/734830/
# 4           /ru/companies/selectel/articles/734860/
# ..                                              ...
# 995                            /ru/articles/728896/
# 996  /ru/companies/sportmaster_lab/articles/728880/
# 997                            /ru/articles/723668/
# 998                            /ru/articles/728870/
# 999                            /ru/articles/728868/
#
#                                              item name Время чтения  \
# 0    Мультяшная графика продаётся лучше реалистично...
# 1    Picture in Picture Mode в android. Показываем ...
# 2                 Много нас, а GPU один. Как делиться?
# 3    Ближайшие бесплатные мероприятия по разработке...
# 4    Одноплатник Orange Pi 5 Plus: характеристики и...
# ..                                                 ...          ...
# 995          Java на стероидах, или опыт работы с Jmix
# 996           «Чистый» код, ужасная производительность
# 997  PostgreSQL под капотом. Часть 5. Простой SELEC...
# 998                            Чат в терминале на Rust
# 999           ChatGPT на Java пишет renamer для файлов
#
#      Сложность Количество просмотров  В закладках  Комментарии  \
# 0        2.000                   324            1            1
# 1        1.000                   122            3            0
# 2        1.000                  1.6K            5            6
# 3        1.000                   376            1            0
# 4        1.038                  3.5K            6           13
# ..         ...                   ...          ...          ...
# 995      2.000                  3.3K           20            2
# 996      1.038                   54K          235          365
# 997      1.038                  3.2K           68            4
# 998      1.000                  3.4K           31            4
# 999      1.000                  2.4K           12            7
#
#      Рейтинг автора   Время публикации     мин
# 0               0.0  2023-05-13, 19:20   8 мин
# 1               0.0  2023-05-13, 18:55   5 мин
# 2               6.1  2023-05-13, 17:57   6 мин
# 3              -0.8  2023-05-13, 16:27   2 мин
# 4              49.0  2023-05-13, 12:55   4 мин
# ..              ...                ...     ...
# 995             0.0  2023-04-13, 14:43   7 мин
# 996            49.2  2023-04-13, 14:23  16 мин
# 997             6.5  2023-04-13, 14:00  42 мин
# 998             5.0  2023-04-13, 13:41  36 мин
# 999             4.0  2023-04-13, 13:41   4 мин
#
# [1000 rows x 10 columns]

# %%
df
# Out:
#                                          Unnamed: 0  \
# 0                              /ru/articles/734892/
# 1                              /ru/articles/734890/
# 2                              /ru/articles/734888/
# 3                              /ru/articles/734830/
# 4           /ru/companies/selectel/articles/734860/
# ..                                              ...
# 995                            /ru/articles/728896/
# 996  /ru/companies/sportmaster_lab/articles/728880/
# 997                            /ru/articles/723668/
# 998                            /ru/articles/728870/
# 999                            /ru/articles/728868/
#
#                                              item name  Сложность  \
# 0    Мультяшная графика продаётся лучше реалистично...      2.000
# 1    Picture in Picture Mode в android. Показываем ...      1.000
# 2                 Много нас, а GPU один. Как делиться?      1.000
# 3    Ближайшие бесплатные мероприятия по разработке...      1.000
# 4    Одноплатник Orange Pi 5 Plus: характеристики и...      1.038
# ..                                                 ...        ...
# 995          Java на стероидах, или опыт работы с Jmix      2.000
# 996           «Чистый» код, ужасная производительность      1.038
# 997  PostgreSQL под капотом. Часть 5. Простой SELEC...      1.038
# 998                            Чат в терминале на Rust      1.000
# 999           ChatGPT на Java пишет renamer для файлов      1.000
#
#     Количество просмотров  В закладках  Комментарии  Рейтинг автора  \
# 0                     324            1            1             0.0
# 1                     122            3            0             0.0
# 2                    1.6K            5            6             6.1
# 3                     376            1            0            -0.8
# 4                    3.5K            6           13            49.0
# ..                    ...          ...          ...             ...
# 995                  3.3K           20            2             0.0
# 996                   54K          235          365            49.2
# 997                  3.2K           68            4             6.5
# 998                  3.4K           31            4             5.0
# 999                  2.4K           12            7             4.0
#
#       Время публикации     мин
# 0    2023-05-13, 19:20   8 мин
# 1    2023-05-13, 18:55   5 мин
# 2    2023-05-13, 17:57   6 мин
# 3    2023-05-13, 16:27   2 мин
# 4    2023-05-13, 12:55   4 мин
# ..                 ...     ...
# 995  2023-04-13, 14:43   7 мин
# 996  2023-04-13, 14:23  16 мин
# 997  2023-04-13, 14:00  42 мин
# 998  2023-04-13, 13:41  36 мин
# 999  2023-04-13, 13:41   4 мин
#
# [1000 rows x 9 columns]

# %%
df[['Время чтения', 'мин']] = df['мин']. str.split(' ', 1 , expand= True )

# %%
df
# Out:
#                                          Unnamed: 0  \
# 0                              /ru/articles/734892/
# 1                              /ru/articles/734890/
# 2                              /ru/articles/734888/
# 3                              /ru/articles/734830/
# 4           /ru/companies/selectel/articles/734860/
# ..                                              ...
# 995                            /ru/articles/728896/
# 996  /ru/companies/sportmaster_lab/articles/728880/
# 997                            /ru/articles/723668/
# 998                            /ru/articles/728870/
# 999                            /ru/articles/728868/
#
#                                              item name  Сложность  \
# 0    Мультяшная графика продаётся лучше реалистично...      2.000
# 1    Picture in Picture Mode в android. Показываем ...      1.000
# 2                 Много нас, а GPU один. Как делиться?      1.000
# 3    Ближайшие бесплатные мероприятия по разработке...      1.000
# 4    Одноплатник Orange Pi 5 Plus: характеристики и...      1.038
# ..                                                 ...        ...
# 995          Java на стероидах, или опыт работы с Jmix      2.000
# 996           «Чистый» код, ужасная производительность      1.038
# 997  PostgreSQL под капотом. Часть 5. Простой SELEC...      1.038
# 998                            Чат в терминале на Rust      1.000
# 999           ChatGPT на Java пишет renamer для файлов      1.000
#
#     Количество просмотров  В закладках  Комментарии  Рейтинг автора  \
# 0                     324            1            1             0.0
# 1                     122            3            0             0.0
# 2                    1.6K            5            6             6.1
# 3                     376            1            0            -0.8
# 4                    3.5K            6           13            49.0
# ..                    ...          ...          ...             ...
# 995                  3.3K           20            2             0.0
# 996                   54K          235          365            49.2
# 997                  3.2K           68            4             6.5
# 998                  3.4K           31            4             5.0
# 999                  2.4K           12            7             4.0
#
#       Время публикации  мин Время чтения
# 0    2023-05-13, 19:20  мин            8
# 1    2023-05-13, 18:55  мин            5
# 2    2023-05-13, 17:57  мин            6
# 3    2023-05-13, 16:27  мин            2
# 4    2023-05-13, 12:55  мин            4
# ..                 ...  ...          ...
# 995  2023-04-13, 14:43  мин            7
# 996  2023-04-13, 14:23  мин           16
# 997  2023-04-13, 14:00  мин           42
# 998  2023-04-13, 13:41  мин           36
# 999  2023-04-13, 13:41  мин            4
#
# [1000 rows x 10 columns]

# %%
df.pop('мин')
# Out:
# 0      мин
# 1      мин
# 2      мин
# 3      мин
# 4      мин
#       ...
# 995    мин
# 996    мин
# 997    мин
# 998    мин
# 999    мин
# Name: мин, Length: 1000, dtype: object

# %%
df
# Out:
#                                          Unnamed: 0  \
# 0                              /ru/articles/734892/
# 1                              /ru/articles/734890/
# 2                              /ru/articles/734888/
# 3                              /ru/articles/734830/
# 4           /ru/companies/selectel/articles/734860/
# ..                                              ...
# 995                            /ru/articles/728896/
# 996  /ru/companies/sportmaster_lab/articles/728880/
# 997                            /ru/articles/723668/
# 998                            /ru/articles/728870/
# 999                            /ru/articles/728868/
#
#                                              item name  Сложность  \
# 0    Мультяшная графика продаётся лучше реалистично...      2.000
# 1    Picture in Picture Mode в android. Показываем ...      1.000
# 2                 Много нас, а GPU один. Как делиться?      1.000
# 3    Ближайшие бесплатные мероприятия по разработке...      1.000
# 4    Одноплатник Orange Pi 5 Plus: характеристики и...      1.038
# ..                                                 ...        ...
# 995          Java на стероидах, или опыт работы с Jmix      2.000
# 996           «Чистый» код, ужасная производительность      1.038
# 997  PostgreSQL под капотом. Часть 5. Простой SELEC...      1.038
# 998                            Чат в терминале на Rust      1.000
# 999           ChatGPT на Java пишет renamer для файлов      1.000
#
#     Количество просмотров  В закладках  Комментарии  Рейтинг автора  \
# 0                     324            1            1             0.0
# 1                     122            3            0             0.0
# 2                    1.6K            5            6             6.1
# 3                     376            1            0            -0.8
# 4                    3.5K            6           13            49.0
# ..                    ...          ...          ...             ...
# 995                  3.3K           20            2             0.0
# 996                   54K          235          365            49.2
# 997                  3.2K           68            4             6.5
# 998                  3.4K           31            4             5.0
# 999                  2.4K           12            7             4.0
#
#       Время публикации Время чтения
# 0    2023-05-13, 19:20            8
# 1    2023-05-13, 18:55            5
# 2    2023-05-13, 17:57            6
# 3    2023-05-13, 16:27            2
# 4    2023-05-13, 12:55            4
# ..                 ...          ...
# 995  2023-04-13, 14:43            7
# 996  2023-04-13, 14:23           16
# 997  2023-04-13, 14:00           42
# 998  2023-04-13, 13:41           36
# 999  2023-04-13, 13:41            4
#
# [1000 rows x 9 columns]

# %%
df = df.astype({'Время чтения': np.float})
# Out:
# C:\Users\Ирина\AppData\Local\Temp\ipykernel_19028\2435078861.py:1: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   df = df.astype({'Время чтения': np.float})

# %%
import numpy as np

# %%
df = df.astype({'Время чтения': np.int64})

# %%
df
# Out:
#                                          Unnamed: 0  \
# 0                              /ru/articles/734892/
# 1                              /ru/articles/734890/
# 2                              /ru/articles/734888/
# 3                              /ru/articles/734830/
# 4           /ru/companies/selectel/articles/734860/
# ..                                              ...
# 995                            /ru/articles/728896/
# 996  /ru/companies/sportmaster_lab/articles/728880/
# 997                            /ru/articles/723668/
# 998                            /ru/articles/728870/
# 999                            /ru/articles/728868/
#
#                                              item name  Сложность  \
# 0    Мультяшная графика продаётся лучше реалистично...      2.000
# 1    Picture in Picture Mode в android. Показываем ...      1.000
# 2                 Много нас, а GPU один. Как делиться?      1.000
# 3    Ближайшие бесплатные мероприятия по разработке...      1.000
# 4    Одноплатник Orange Pi 5 Plus: характеристики и...      1.038
# ..                                                 ...        ...
# 995          Java на стероидах, или опыт работы с Jmix      2.000
# 996           «Чистый» код, ужасная производительность      1.038
# 997  PostgreSQL под капотом. Часть 5. Простой SELEC...      1.038
# 998                            Чат в терминале на Rust      1.000
# 999           ChatGPT на Java пишет renamer для файлов      1.000
#
#     Количество просмотров  В закладках  Комментарии  Рейтинг автора  \
# 0                     324            1            1             0.0
# 1                     122            3            0             0.0
# 2                    1.6K            5            6             6.1
# 3                     376            1            0            -0.8
# 4                    3.5K            6           13            49.0
# ..                    ...          ...          ...             ...
# 995                  3.3K           20            2             0.0
# 996                   54K          235          365            49.2
# 997                  3.2K           68            4             6.5
# 998                  3.4K           31            4             5.0
# 999                  2.4K           12            7             4.0
#
#       Время публикации  Время чтения
# 0    2023-05-13, 19:20             8
# 1    2023-05-13, 18:55             5
# 2    2023-05-13, 17:57             6
# 3    2023-05-13, 16:27             2
# 4    2023-05-13, 12:55             4
# ..                 ...           ...
# 995  2023-04-13, 14:43             7
# 996  2023-04-13, 14:23            16
# 997  2023-04-13, 14:00            42
# 998  2023-04-13, 13:41            36
# 999  2023-04-13, 13:41             4
#
# [1000 rows x 9 columns]
