# %%
df = pd.read_csv('habr_cleared_data.csv')

# %%
import pandas as pd
import numpy as np

# %%
df
# Out:
#      Unnamed: 0                                          item name  \
# 0             0  Мультяшная графика продаётся лучше реалистично...
# 1             1  Picture in Picture Mode в android. Показываем ...
# 2             2               Много нас, а GPU один. Как делиться?
# 3             3  Ближайшие бесплатные мероприятия по разработке...
# 4             4  Одноплатник Orange Pi 5 Plus: характеристики и...
# ..          ...                                                ...
# 995         995          Java на стероидах, или опыт работы с Jmix
# 996         996           «Чистый» код, ужасная производительность
# 997         997  PostgreSQL под капотом. Часть 5. Простой SELEC...
# 998         998                            Чат в терминале на Rust
# 999         999           ChatGPT на Java пишет renamer для файлов
#
#      Время чтения Сложность  Количество просмотров  В закладках  Комментарии  \
# 0               8         2                  324.0            1            1
# ...

# %%
# новый признак - сохранения/просмотры
df['Savings_per_Views'] = df['В закладках']/df['Количество просмотров']

# %%
# новый признак: нормализация признака 'Время чтения', чтобы при тестировании гипотез можно было сравнить с дркгими признаками
df['norm_ReadingTime'] = (df['Время чтения'] - df['Время чтения'].min()) / (df['Время чтения'].max() - df['Время чтения'].min())

# %%
df
# Out:
#      Unnamed: 0                                          item name  \
# 0             0  Мультяшная графика продаётся лучше реалистично...
# 1             1  Picture in Picture Mode в android. Показываем ...
# 2             2               Много нас, а GPU один. Как делиться?
# 3             3  Ближайшие бесплатные мероприятия по разработке...
# 4             4  Одноплатник Orange Pi 5 Plus: характеристики и...
# ..          ...                                                ...
# 995         995          Java на стероидах, или опыт работы с Jmix
# 996         996           «Чистый» код, ужасная производительность
# 997         997  PostgreSQL под капотом. Часть 5. Простой SELEC...
# 998         998                            Чат в терминале на Rust
# 999         999           ChatGPT на Java пишет renamer для файлов
#
#      Время чтения Сложность  Количество просмотров  В закладках  Комментарии  \
# 0               8         2                  324.0            1            1
# ...

# %%
# формат datetime
df['Время публикации'] = pd.to_datetime(df['Время публикации'])

# новый признак: создаю новую колонку с часом публикации. В будущем мы это применим в тестировании гипотез, чтобы посмотреть зависимость между количеством сохранений и часом публикации
df['hour'] = df['Время публикации'].dt.hour

# %%
df
# Out:
#      Unnamed: 0                                          item name  \
# 0             0  Мультяшная графика продаётся лучше реалистично...
# 1             1  Picture in Picture Mode в android. Показываем ...
# 2             2               Много нас, а GPU один. Как делиться?
# 3             3  Ближайшие бесплатные мероприятия по разработке...
# 4             4  Одноплатник Orange Pi 5 Plus: характеристики и...
# ..          ...                                                ...
# 995         995          Java на стероидах, или опыт работы с Jmix
# 996         996           «Чистый» код, ужасная производительность
# 997         997  PostgreSQL под капотом. Часть 5. Простой SELEC...
# 998         998                            Чат в терминале на Rust
# 999         999           ChatGPT на Java пишет renamer для файлов
#
#      Время чтения Сложность  Количество просмотров  В закладках  Комментарии  \
# 0               8         2                  324.0            1            1
# ...
