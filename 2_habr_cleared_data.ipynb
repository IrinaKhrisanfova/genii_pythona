# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('C://Users//Ирина//Downloads//habr_data (2).csv')

# %%
# удаляю ненужную колонку
df.pop('Unnamed: 0')
# Out:
# 0                                /ru/articles/734892/
# 1                                /ru/articles/734890/
# 2                                /ru/articles/734888/
# 3                                /ru/articles/734830/
# 4             /ru/companies/selectel/articles/734860/
#                             ...
# 995                              /ru/articles/728896/
# 996    /ru/companies/sportmaster_lab/articles/728880/
# 997                              /ru/articles/723668/
# 998                              /ru/articles/728870/
# 999                              /ru/articles/728868/
# Name: Unnamed: 0, Length: 1000, dtype: object

# %%
df
# Out:
#                                              item name Время чтения Сложность  \
# 0    Мультяшная графика продаётся лучше реалистично...        8 мин   Средний
# 1    Picture in Picture Mode в android. Показываем ...        5 мин   Простой
# 2                 Много нас, а GPU один. Как делиться?        6 мин   Простой
# 3    Ближайшие бесплатные мероприятия по разработке...        2 мин   Простой
# 4    Одноплатник Orange Pi 5 Plus: характеристики и...        4 мин       NaN
# ..                                                 ...          ...       ...
# 995          Java на стероидах, или опыт работы с Jmix        7 мин   Средний
# 996           «Чистый» код, ужасная производительность       16 мин       NaN
# 997  PostgreSQL под капотом. Часть 5. Простой SELEC...       42 мин       NaN
# 998                            Чат в терминале на Rust       36 мин   Простой
# 999           ChatGPT на Java пишет renamer для файлов        4 мин   Простой
#
# ...

# %%
# заменяю пустые значения на 0
df['Сложность'] = df['Сложность'].fillna(0)

# делаю кодировку 
df['Сложность'] = df['Сложность'].replace(['Простой', 'Средний', 'Сложный'],[1, 2, 3])

# %%
# меняю 0 на запятые, чтобы не влияли на значения
df['Сложность'] = df['Сложность'].replace([0],[','])

# превращаю численно-буквенный вид в численный
df[['Время чтения', 'мин']] = df['Время чтения']. str.split(' ', 1 , expand= True )
df.pop('мин')
df = df.astype({'Время чтения': np.int64})

# %%
# "К" превращаю в тысячи
def value_to_float(x):
    if 'K' in x:
        return float(x.replace('K', '')) * 1000
    else:
        return float(x)
df['Количество просмотров'] =  df['Количество просмотров'].apply(value_to_float)

# %%
df
# Out:
#                                              item name  Время чтения  \
# 0    Мультяшная графика продаётся лучше реалистично...             8
# 1    Picture in Picture Mode в android. Показываем ...             5
# 2                 Много нас, а GPU один. Как делиться?             6
# 3    Ближайшие бесплатные мероприятия по разработке...             2
# 4    Одноплатник Orange Pi 5 Plus: характеристики и...             4
# ..                                                 ...           ...
# 995          Java на стероидах, или опыт работы с Jmix             7
# 996           «Чистый» код, ужасная производительность            16
# 997  PostgreSQL под капотом. Часть 5. Простой SELEC...            42
# 998                            Чат в терминале на Rust            36
# 999           ChatGPT на Java пишет renamer для файлов             4
#
#     Сложность  Количество просмотров  В закладках  Комментарии         Автор  \
# ...

# %%
# превращаю в дататайм
df['Время публикации'] = pd.to_datetime(df['Время публикации'])

# %%
df
# Out:
#                                              item name  Время чтения  \
# 0    Мультяшная графика продаётся лучше реалистично...             8
# 1    Picture in Picture Mode в android. Показываем ...             5
# 2                 Много нас, а GPU один. Как делиться?             6
# 3    Ближайшие бесплатные мероприятия по разработке...             2
# 4    Одноплатник Orange Pi 5 Plus: характеристики и...             4
# ..                                                 ...           ...
# 995          Java на стероидах, или опыт работы с Jmix             7
# 996           «Чистый» код, ужасная производительность            16
# 997  PostgreSQL под капотом. Часть 5. Простой SELEC...            42
# 998                            Чат в терминале на Rust            36
# 999           ChatGPT на Java пишет renamer для файлов             4
#
#     Сложность  Количество просмотров  В закладках  Комментарии         Автор  \
# ...

# %%
df.to_csv("habr_cleared_data.csv")
